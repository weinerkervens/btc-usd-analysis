# %% [markdown]
# ---

# %%
# Useful Imports

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# ### Checking the good style to apply

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %% [markdown]
# for style in plt.style.available:
#     print(style)
#     mpl.style.use(style)
#     plot_evol('Bitcoin',btc,'2019','Close')

# %% [markdown]
# ---

# %%
mpl.style.use('seaborn-whitegrid')

# %% [markdown]
# ---

# %% [markdown]
# <center><h2>Functions definition</h2></center>

# %%
# Function to import timeseries datasets

def import_df(name,index_col='Date'):
    ext = '.csv'
    root = 'data/'
    df = pd.read_csv(root+name+ext,index_col=index_col,parse_dates=True)
    return df

# %%
# Function to display evolution of currency

def plot_evol(name,data,year,feature):
    plt.figure(figsize=(15,5))
    data[year][feature].plot()
    data[year][feature].resample('M').mean().plot(label='Moyenne par mois', lw=3,alpha=0.8)
    data[year][feature].resample('M').std().plot(label='Variation par mois', lw=3,ls='--',alpha=0.8)
    data[year][feature].diff().plot(label='Volatilité',alpha=0.8)
    plt.title(f'Evolution du {name} en {year}\n')
    plt.ylabel('Prix en USD')
    plt.legend()
    plt.show()

# %% [markdown]
# ---

# %%
# Importing BTC dataset

btc = import_df('BTC-USD')
btc.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# Date
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %%
# Importing ETH dataset

eth = import_df('ETH-USD')
eth.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2015-08-07  2.831620  3.536610  2.521120  2.772120   2.772120   164329
# 2015-08-08  2.793760  2.798810  0.714725  0.753325   0.753325   674188
# 2015-08-09  0.706136  0.879810  0.629191  0.701897   0.701897   532170
# 2015-08-10  0.713989  0.729854  0.636546  0.708448   0.708448   405283
# 2015-08-11  0.708087  1.131410  0.663235  1.067860   1.067860  1463100

# %%
# Importing HTG dataset

htg = import_df('USD-HTG')
htg.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2003-12-01  40.369999  40.369999  40.369999  40.369999  40.369999     0.0
# 2003-12-02  40.319000  40.319000  40.319000  40.319000  40.319000     0.0
# 2003-12-03  39.852001  39.852001  39.852001  39.852001  39.852001     0.0
# 2003-12-04  40.084000  40.084000  40.084000  40.084000  40.084000     0.0
# 2003-12-05  40.099998  40.099998  40.099998  40.099998  40.099998     0.0

# %%
plt.figure(figsize=(15,8))
btc['2017-09':]['Close'].plot(label='BTC',lw=1, alpha=1)
eth['2017-09':]['Close'].plot(label='ETH',alpha=.5)
#htg['2015-09':]['Close'].plot(label='HTG',alpha=.4)
#btc['2015-09':]['Close'].max().plot(kind='scatter',label='BTC',ls='*',lw=1, alpha=1)
#plt.plot(x=)
plt.ylabel('Price in USD')
plt.legend()

# %% [markdown]
# ---

# %%
plot_evol('Bitcoin',btc,'2019','Close')

# %%
plot_evol('Bitcoin',btc,'2020','Close')

# %%
plot_evol('HTG',htg,'2020','Close')

# %%
plot_evol('ETH',eth,'2020','Close')

# %%
plt.figure(figsize=(15,5))
btc['Close']['2017-10':'2018-03'].diff().plot()

# %%
month = eth['Close'].idxmax().month_name()
day = eth['Close'].idxmax().day
year = eth['Close'].idxmax().year

# %%
max_value_all_time = round(eth['Close'].max(),1)
print(f'On {month} {day}, {year} Bitcoin was worth ${max_value_all_time}.')
# Out:
# On January 13, 2018 Bitcoin was worth $1396.4.

# %% [markdown]
# <!--cols = df_2.columns.to_list()
# cols-->

# %% [markdown]
# <!--df3 = df_2-->

# %% [markdown]
# <!--for col in cols:
#     df3.loc[:,col] = df_2.loc[:,col]*df.loc[:,col]
# df3.head()-->

# %% [markdown]
# <!--43*465-->

# %% [markdown]
# <!--df3['2014':]['Close'].plot()-->

# %% [markdown]
# <center>Copyright <b>Weiner-Kervens Pierre<b></center>
